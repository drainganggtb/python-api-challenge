# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
import random
from scipy import stats as st
from pprint import pprint
from citipy import citipy
import openweathermapy as owm
#import API key
from api_keys import weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
# Range of latitudes and longitudes, just for reference
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
cities=[]
while len(cities)<600:
    lat = (random.choice(range(-90,90)))
    long = (random.choice(range(-180,180)))
    city= citipy.nearest_city(lat,long).city_name
    if city not in cities:
        cities.append(city)

# %%
print(len(cities))
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#url api call
url = "http://api.openweathermap.org/data/2.5/weather?"
units="imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
#Initialize data frame to store data from API calls
WeatherPy_df =pd.DataFrame(columns = ["City","Latitude","Longitude", "Temperature (F)"])

# %%
city_length=len(cities)
count = 1 #count number calls to api

print(f'Beginning Data Retrival from OpenWeather API \n ...........................................')
for city in cities:
    try:        
        print(f'Processing Record {count} of {city_length} | {city}')
        count +=1
        response=requests.get(query_url+city).json()
        temp=response['main']['temp']
        humid=response['main']['humidity']
        cloud=response['clouds']['all']
        wind=response['wind']['speed']
        lat1=response['coord']['lat']
        lon1=response['coord']['lon']
        
        line_df= pd.DataFrame([{"City": city, "Latitude": lat1, "Longitude": lon1,"Temperature (F)": response['main']['temp'], "Humidity (%)": response['main']['humidity'], "Cloudiness (%)": response['clouds']['all'], "Wind Speed (mph)": response['wind']['speed']}])
        WeatherPy_df=WeatherPy_df.append(line_df,ignore_index=True)
    except:
        print("No data found...")
# Out:
# Beginning Data Retrival from OpenWeather API
#  ...........................................
# Processing Record 1 of 600 | arraial do cabo
# Processing Record 2 of 600 | dikson
# Processing Record 3 of 600 | sabang
# Processing Record 4 of 600 | coquimbo
# Processing Record 5 of 600 | carnarvon
# Processing Record 6 of 600 | chokurdakh
# Processing Record 7 of 600 | tuktoyaktuk
# Processing Record 8 of 600 | new norfolk
# Processing Record 9 of 600 | cape town
# Processing Record 10 of 600 | curuca
# Processing Record 11 of 600 | yungkang
# No data found...
# Processing Record 12 of 600 | namtsy
# Processing Record 13 of 600 | hermanus
# Processing Record 14 of 600 | faanui
# Processing Record 15 of 600 | peceneaga
# Processing Record 16 of 600 | asayita
# No data found...
# Processing Record 17 of 600 | port alfred
# Processing Record 18 of 600 | natal
# Processing Record 19 of 600 | mount gambier
# Processing Record 20 of 600 | kiama
# Processing Record 21 of 600 | paamiut
# Processing Record 22 of 600 | punta arenas
# Processing Record 23 of 600 | yirol
# No data found...
# Processing Record 24 of 600 | iqaluit
# Processing Record 25 of 600 | wilmington
# Processing Record 26 of 600 | gizo
# Processing Record 27 of 600 | ushuaia
# Processing Record 28 of 600 | novopokrovka
# Processing Record 29 of 600 | hobart
# Processing Record 30 of 600 | bumba
# Processing Record 31 of 600 | kawalu
# Processing Record 32 of 600 | port lincoln
# Processing Record 33 of 600 | clyde river
# Processing Record 34 of 600 | taolanaro
# No data found...
# Processing Record 35 of 600 | telimele
# Processing Record 36 of 600 | aquiraz
# Processing Record 37 of 600 | bulaevo
# Processing Record 38 of 600 | rikitea
# Processing Record 39 of 600 | rovaniemi
# Processing Record 40 of 600 | illoqqortoormiut
# No data found...
# Processing Record 41 of 600 | bengkulu
# Processing Record 42 of 600 | albany
# Processing Record 43 of 600 | yellowknife
# Processing Record 44 of 600 | butaritari
# Processing Record 45 of 600 | neuquen
# Processing Record 46 of 600 | bukama
# Processing Record 47 of 600 | sentyabrskiy
# No data found...
# Processing Record 48 of 600 | pisco
# Processing Record 49 of 600 | jacareacanga
# Processing Record 50 of 600 | guerrero negro
# Processing Record 51 of 600 | imperial
# Processing Record 52 of 600 | samusu
# No data found...
# Processing Record 53 of 600 | grindavik
# Processing Record 54 of 600 | jinchang
# Processing Record 55 of 600 | east london
# Processing Record 56 of 600 | saint anthony
# Processing Record 57 of 600 | yinchuan
# Processing Record 58 of 600 | lagoa
# Processing Record 59 of 600 | cockburn town
# Processing Record 60 of 600 | morros
# Processing Record 61 of 600 | mataura
# Processing Record 62 of 600 | tasiilaq
# Processing Record 63 of 600 | saint-denis
# Processing Record 64 of 600 | kodiak
# Processing Record 65 of 600 | khash
# Processing Record 66 of 600 | abha
# Processing Record 67 of 600 | kanjiza
# Processing Record 68 of 600 | muravlenko
# Processing Record 69 of 600 | thompson
# Processing Record 70 of 600 | norman wells
# Processing Record 71 of 600 | kahului
# Processing Record 72 of 600 | yazman
# Processing Record 73 of 600 | ilulissat
# Processing Record 74 of 600 | kaitangata
# Processing Record 75 of 600 | sinnamary
# Processing Record 76 of 600 | bredasdorp
# Processing Record 77 of 600 | sarangani
# Processing Record 78 of 600 | cabedelo
# Processing Record 79 of 600 | rastolita
# Processing Record 80 of 600 | igarka
# Processing Record 81 of 600 | saint george
# Processing Record 82 of 600 | san ignacio
# Processing Record 83 of 600 | hualmay
# Processing Record 84 of 600 | pangai
# Processing Record 85 of 600 | atuona
# Processing Record 86 of 600 | cabo san lucas
# Processing Record 87 of 600 | sal rei
# Processing Record 88 of 600 | laguna
# Processing Record 89 of 600 | gushikawa
# Processing Record 90 of 600 | myre
# Processing Record 91 of 600 | dordrecht
# Processing Record 92 of 600 | lac du bonnet
# Processing Record 93 of 600 | kapit
# Processing Record 94 of 600 | rio tuba
# Processing Record 95 of 600 | busselton
# Processing Record 96 of 600 | tezu
# Processing Record 97 of 600 | vyartsilya
# Processing Record 98 of 600 | thinadhoo
# Processing Record 99 of 600 | erenhot
# Processing Record 100 of 600 | livramento
# Processing Record 101 of 600 | manggar
# Processing Record 102 of 600 | auki
# Processing Record 103 of 600 | mocuba
# Processing Record 104 of 600 | wajid
# Processing Record 105 of 600 | tsihombe
# No data found...
# Processing Record 106 of 600 | khatanga
# Processing Record 107 of 600 | bandundu
# Processing Record 108 of 600 | hays
# Processing Record 109 of 600 | fort saint john
# No data found...
# Processing Record 110 of 600 | portland
# Processing Record 111 of 600 | saleaula
# No data found...
# Processing Record 112 of 600 | pevek
# Processing Record 113 of 600 | vaini
# Processing Record 114 of 600 | geraldton
# Processing Record 115 of 600 | cherskiy
# Processing Record 116 of 600 | humberto de campos
# Processing Record 117 of 600 | qasigiannguit
# Processing Record 118 of 600 | coruripe
# Processing Record 119 of 600 | toba
# Processing Record 120 of 600 | santiago
# Processing Record 121 of 600 | san cristobal
# Processing Record 122 of 600 | rennes
# Processing Record 123 of 600 | jamestown
# Processing Record 124 of 600 | frontera
# Processing Record 125 of 600 | hithadhoo
# Processing Record 126 of 600 | puerto ayora
# Processing Record 127 of 600 | antalaha
# Processing Record 128 of 600 | esna
# Processing Record 129 of 600 | bathsheba
# Processing Record 130 of 600 | sassenberg
# Processing Record 131 of 600 | mys shmidta
# No data found...
# Processing Record 132 of 600 | albion
# Processing Record 133 of 600 | severnyy
# Processing Record 134 of 600 | sokoni
# Processing Record 135 of 600 | vila
# Processing Record 136 of 600 | thunder bay
# Processing Record 137 of 600 | bluff
# Processing Record 138 of 600 | balykshi
# Processing Record 139 of 600 | ponta do sol
# Processing Record 140 of 600 | chuy
# Processing Record 141 of 600 | syracuse
# Processing Record 142 of 600 | nemuro
# Processing Record 143 of 600 | hilo
# Processing Record 144 of 600 | lazaro cardenas
# Processing Record 145 of 600 | mezen
# Processing Record 146 of 600 | bandarbeyla
# Processing Record 147 of 600 | wana
# Processing Record 148 of 600 | manakara
# Processing Record 149 of 600 | puerto castilla
# Processing Record 150 of 600 | vaitupu
# No data found...
# Processing Record 151 of 600 | kruisfontein
# Processing Record 152 of 600 | pitkyaranta
# Processing Record 153 of 600 | chippewa falls
# Processing Record 154 of 600 | gat
# Processing Record 155 of 600 | itaocara
# Processing Record 156 of 600 | coihaique
# Processing Record 157 of 600 | marcona
# No data found...
# Processing Record 158 of 600 | samfya
# Processing Record 159 of 600 | bolungarvik
# No data found...
# Processing Record 160 of 600 | tairua
# Processing Record 161 of 600 | tabou
# Processing Record 162 of 600 | barrow
# Processing Record 163 of 600 | antofagasta
# Processing Record 164 of 600 | hobyo
# Processing Record 165 of 600 | moundsville
# Processing Record 166 of 600 | isangel
# Processing Record 167 of 600 | belushya guba
# No data found...
# Processing Record 168 of 600 | fereydunshahr
# Processing Record 169 of 600 | samana
# Processing Record 170 of 600 | vallenar
# Processing Record 171 of 600 | qaanaaq
# Processing Record 172 of 600 | mergui
# No data found...
# Processing Record 173 of 600 | barentsburg
# No data found...
# Processing Record 174 of 600 | hurricane
# Processing Record 175 of 600 | esperance
# Processing Record 176 of 600 | nizhneyansk
# No data found...
# Processing Record 177 of 600 | umm kaddadah
# Processing Record 178 of 600 | rocha
# Processing Record 179 of 600 | contai
# Processing Record 180 of 600 | nadadores
# Processing Record 181 of 600 | castro
# Processing Record 182 of 600 | lucapa
# Processing Record 183 of 600 | batagay
# Processing Record 184 of 600 | roswell
# Processing Record 185 of 600 | kapaa
# Processing Record 186 of 600 | kragujevac
# Processing Record 187 of 600 | mehamn
# Processing Record 188 of 600 | baykit
# Processing Record 189 of 600 | tiksi
# Processing Record 190 of 600 | aklavik
# Processing Record 191 of 600 | blackwater
# Processing Record 192 of 600 | esmeraldas
# Processing Record 193 of 600 | vila velha
# Processing Record 194 of 600 | kabalo
# Processing Record 195 of 600 | schenectady
# Processing Record 196 of 600 | menongue
# Processing Record 197 of 600 | varhaug
# Processing Record 198 of 600 | ribeira grande
# Processing Record 199 of 600 | nadym
# Processing Record 200 of 600 | college
# Processing Record 201 of 600 | port elizabeth
# Processing Record 202 of 600 | carutapera
# Processing Record 203 of 600 | la ronge
# Processing Record 204 of 600 | bambous virieux
# Processing Record 205 of 600 | machico
# Processing Record 206 of 600 | san patricio
# Processing Record 207 of 600 | barreirinhas
# Processing Record 208 of 600 | najran
# Processing Record 209 of 600 | evensk
# Processing Record 210 of 600 | tubuala
# Processing Record 211 of 600 | awbari
# Processing Record 212 of 600 | margate
# Processing Record 213 of 600 | pangnirtung
# Processing Record 214 of 600 | yatou
# Processing Record 215 of 600 | longyearbyen
# Processing Record 216 of 600 | cinnaminson
# Processing Record 217 of 600 | victoria
# Processing Record 218 of 600 | marawi
# Processing Record 219 of 600 | druskininkai
# Processing Record 220 of 600 | landskrona
# Processing Record 221 of 600 | ahipara
# Processing Record 222 of 600 | tolaga bay
# Processing Record 223 of 600 | mar del plata
# Processing Record 224 of 600 | gualeguay
# Processing Record 225 of 600 | mount isa
# Processing Record 226 of 600 | sitka
# Processing Record 227 of 600 | cidreira
# Processing Record 228 of 600 | ambon
# Processing Record 229 of 600 | vardo
# Processing Record 230 of 600 | liverpool
# Processing Record 231 of 600 | nueva helvecia
# Processing Record 232 of 600 | riyadh
# Processing Record 233 of 600 | tawkar
# No data found...
# Processing Record 234 of 600 | khandyga
# Processing Record 235 of 600 | biak
# Processing Record 236 of 600 | airai
# Processing Record 237 of 600 | knin
# Processing Record 238 of 600 | macusani
# Processing Record 239 of 600 | hervey bay
# Processing Record 240 of 600 | rawson
# Processing Record 241 of 600 | maridi
# Processing Record 242 of 600 | nikolskoye
# Processing Record 243 of 600 | sistranda
# Processing Record 244 of 600 | muisne
# Processing Record 245 of 600 | lowicz
# Processing Record 246 of 600 | corinth
# Processing Record 247 of 600 | shimoda
# Processing Record 248 of 600 | amderma
# No data found...
# Processing Record 249 of 600 | havelock
# Processing Record 250 of 600 | male
# Processing Record 251 of 600 | goure
# Processing Record 252 of 600 | torbay
# Processing Record 253 of 600 | campoverde
# Processing Record 254 of 600 | grand river south east
# No data found...
# Processing Record 255 of 600 | yagodnoye
# Processing Record 256 of 600 | iracoubo
# Processing Record 257 of 600 | gollere
# No data found...
# Processing Record 258 of 600 | kazuno
# Processing Record 259 of 600 | pastos bons
# Processing Record 260 of 600 | porto novo
# Processing Record 261 of 600 | kenai
# Processing Record 262 of 600 | itarema
# Processing Record 263 of 600 | toledo
# Processing Record 264 of 600 | anzhero-sudzhensk
# Processing Record 265 of 600 | uhlove
# Processing Record 266 of 600 | general roca
# Processing Record 267 of 600 | libourne
# Processing Record 268 of 600 | san quintin
# Processing Record 269 of 600 | plettenberg bay
# Processing Record 270 of 600 | yumen
# Processing Record 271 of 600 | ponta delgada
# Processing Record 272 of 600 | mentougou
# Processing Record 273 of 600 | sorland
# Processing Record 274 of 600 | sakaiminato
# Processing Record 275 of 600 | sabha
# Processing Record 276 of 600 | the pas
# Processing Record 277 of 600 | srivardhan
# Processing Record 278 of 600 | dok kham tai
# Processing Record 279 of 600 | mahebourg
# Processing Record 280 of 600 | umzimvubu
# No data found...
# Processing Record 281 of 600 | mayor pablo lagerenza
# Processing Record 282 of 600 | warqla
# No data found...
# Processing Record 283 of 600 | katsuura
# Processing Record 284 of 600 | sao filipe
# Processing Record 285 of 600 | nicoya
# Processing Record 286 of 600 | sorvag
# No data found...
# Processing Record 287 of 600 | vyazemskiy
# Processing Record 288 of 600 | kadoma
# Processing Record 289 of 600 | seoul
# Processing Record 290 of 600 | kui buri
# Processing Record 291 of 600 | provideniya
# Processing Record 292 of 600 | kaeo
# Processing Record 293 of 600 | lebu
# Processing Record 294 of 600 | washougal
# Processing Record 295 of 600 | madang
# Processing Record 296 of 600 | marsani
# Processing Record 297 of 600 | skjaerhollen
# No data found...
# Processing Record 298 of 600 | te anau
# Processing Record 299 of 600 | maracacume
# Processing Record 300 of 600 | souillac
# Processing Record 301 of 600 | caravelas
# Processing Record 302 of 600 | zhanatas
# No data found...
# Processing Record 303 of 600 | ancud
# Processing Record 304 of 600 | chitral
# Processing Record 305 of 600 | buenavista
# Processing Record 306 of 600 | road town
# Processing Record 307 of 600 | muleba
# Processing Record 308 of 600 | bunbury
# Processing Record 309 of 600 | mildura
# Processing Record 310 of 600 | knysna
# Processing Record 311 of 600 | saldanha
# Processing Record 312 of 600 | ranau
# Processing Record 313 of 600 | acapulco
# Processing Record 314 of 600 | barcelona
# Processing Record 315 of 600 | plastun
# Processing Record 316 of 600 | aljezur
# Processing Record 317 of 600 | agadez
# Processing Record 318 of 600 | nhulunbuy
# Processing Record 319 of 600 | zaozerne
# Processing Record 320 of 600 | talnakh
# Processing Record 321 of 600 | tombouctou
# Processing Record 322 of 600 | mullaitivu
# No data found...
# Processing Record 323 of 600 | cumbernauld
# Processing Record 324 of 600 | severo-kurilsk
# Processing Record 325 of 600 | salalah
# Processing Record 326 of 600 | aswan
# Processing Record 327 of 600 | davila
# Processing Record 328 of 600 | kirakira
# Processing Record 329 of 600 | coolum beach
# Processing Record 330 of 600 | avarua
# Processing Record 331 of 600 | santa vitoria do palmar
# Processing Record 332 of 600 | dubovskoye
# Processing Record 333 of 600 | nanortalik
# Processing Record 334 of 600 | iquitos
# Processing Record 335 of 600 | shache
# Processing Record 336 of 600 | dano
# Processing Record 337 of 600 | ambunti
# Processing Record 338 of 600 | sergeyevka
# Processing Record 339 of 600 | port hardy
# Processing Record 340 of 600 | beloha
# Processing Record 341 of 600 | ilhabela
# Processing Record 342 of 600 | palabuhanratu
# No data found...
# Processing Record 343 of 600 | tuatapere
# Processing Record 344 of 600 | eyl
# Processing Record 345 of 600 | shagonar
# Processing Record 346 of 600 | danshui
# Processing Record 347 of 600 | saint-philippe
# Processing Record 348 of 600 | balabac
# Processing Record 349 of 600 | tagusao
# Processing Record 350 of 600 | leningradskiy
# Processing Record 351 of 600 | los llanos de aridane
# Processing Record 352 of 600 | jaisalmer
# Processing Record 353 of 600 | louisbourg
# No data found...
# Processing Record 354 of 600 | conakry
# Processing Record 355 of 600 | assare
# Processing Record 356 of 600 | dolbeau
# No data found...
# Processing Record 357 of 600 | shakawe
# Processing Record 358 of 600 | lapua
# Processing Record 359 of 600 | hamilton
# Processing Record 360 of 600 | namibe
# Processing Record 361 of 600 | simbahan
# Processing Record 362 of 600 | nouna
# Processing Record 363 of 600 | khandbari
# Processing Record 364 of 600 | itamarandiba
# Processing Record 365 of 600 | vila franca do campo
# Processing Record 366 of 600 | linxia
# Processing Record 367 of 600 | rudnaya pristan
# Processing Record 368 of 600 | ruteng
# Processing Record 369 of 600 | flinders
# Processing Record 370 of 600 | muzquiz
# No data found...
# Processing Record 371 of 600 | fort nelson
# Processing Record 372 of 600 | merauke
# Processing Record 373 of 600 | porto santo
# Processing Record 374 of 600 | ostrovnoy
# Processing Record 375 of 600 | tasbuget
# No data found...
# Processing Record 376 of 600 | attawapiskat
# No data found...
# Processing Record 377 of 600 | zhumadian
# Processing Record 378 of 600 | samalaeulu
# No data found...
# Processing Record 379 of 600 | puro
# Processing Record 380 of 600 | lompoc
# Processing Record 381 of 600 | labuhan
# Processing Record 382 of 600 | tumannyy
# No data found...
# Processing Record 383 of 600 | lavrentiya
# Processing Record 384 of 600 | rafai
# Processing Record 385 of 600 | dalneye konstantinovo
# No data found...
# Processing Record 386 of 600 | saskylakh
# Processing Record 387 of 600 | payson
# Processing Record 388 of 600 | maraa
# Processing Record 389 of 600 | kiunga
# Processing Record 390 of 600 | hasaki
# Processing Record 391 of 600 | meulaboh
# Processing Record 392 of 600 | anchorage
# Processing Record 393 of 600 | mogzon
# Processing Record 394 of 600 | havoysund
# Processing Record 395 of 600 | ordubad
# Processing Record 396 of 600 | tucuma
# Processing Record 397 of 600 | galiwinku
# No data found...
# Processing Record 398 of 600 | hargeysa
# Processing Record 399 of 600 | port-de-paix
# No data found...
# Processing Record 400 of 600 | saint-joseph
# Processing Record 401 of 600 | kavieng
# Processing Record 402 of 600 | gualaco
# Processing Record 403 of 600 | caticlan
# Processing Record 404 of 600 | villa carlos paz
# Processing Record 405 of 600 | port hawkesbury
# Processing Record 406 of 600 | bethel
# Processing Record 407 of 600 | abu samrah
# Processing Record 408 of 600 | novoagansk
# Processing Record 409 of 600 | husavik
# Processing Record 410 of 600 | karaul
# No data found...
# Processing Record 411 of 600 | fairbanks
# Processing Record 412 of 600 | sao marcos
# Processing Record 413 of 600 | winslow
# Processing Record 414 of 600 | praxedis guerrero
# Processing Record 415 of 600 | bubaque
# Processing Record 416 of 600 | pitiquito
# Processing Record 417 of 600 | krasnoselkup
# Processing Record 418 of 600 | isla mujeres
# Processing Record 419 of 600 | burlington
# Processing Record 420 of 600 | nouakchott
# Processing Record 421 of 600 | padang
# Processing Record 422 of 600 | lillooet
# Processing Record 423 of 600 | luderitz
# Processing Record 424 of 600 | siyabuswa
# Processing Record 425 of 600 | verkhoturye
# Processing Record 426 of 600 | fernley
# Processing Record 427 of 600 | lorengau
# Processing Record 428 of 600 | banda
# Processing Record 429 of 600 | moose factory
# Processing Record 430 of 600 | praia
# Processing Record 431 of 600 | kjollefjord
# Processing Record 432 of 600 | georgetown
# Processing Record 433 of 600 | qaqortoq
# Processing Record 434 of 600 | itoman
# Processing Record 435 of 600 | jalu
# Processing Record 436 of 600 | upington
# Processing Record 437 of 600 | leshukonskoye
# Processing Record 438 of 600 | chara
# Processing Record 439 of 600 | sambava
# Processing Record 440 of 600 | carahue
# Processing Record 441 of 600 | sioux lookout
# Processing Record 442 of 600 | north bend
# Processing Record 443 of 600 | pedernales
# Processing Record 444 of 600 | keetmanshoop
# Processing Record 445 of 600 | vieques
# Processing Record 446 of 600 | korla
# Processing Record 447 of 600 | mayo
# Processing Record 448 of 600 | nkongsamba
# Processing Record 449 of 600 | jumla
# Processing Record 450 of 600 | ulaangom
# Processing Record 451 of 600 | taltal
# Processing Record 452 of 600 | panzhihua
# Processing Record 453 of 600 | kota kinabalu
# Processing Record 454 of 600 | ambulu
# Processing Record 455 of 600 | pemangkat
# Processing Record 456 of 600 | bukachacha
# Processing Record 457 of 600 | ngunguru
# Processing Record 458 of 600 | klaksvik
# Processing Record 459 of 600 | esfahan
# Processing Record 460 of 600 | kamenskoye
# No data found...
# Processing Record 461 of 600 | ibotirama
# Processing Record 462 of 600 | praya
# Processing Record 463 of 600 | abrau-dyurso
# Processing Record 464 of 600 | basco
# Processing Record 465 of 600 | solhan
# Processing Record 466 of 600 | talara
# Processing Record 467 of 600 | alofi
# Processing Record 468 of 600 | kifri
# Processing Record 469 of 600 | namatanai
# Processing Record 470 of 600 | trelew
# Processing Record 471 of 600 | raga
# Processing Record 472 of 600 | sao jose da coroa grande
# Processing Record 473 of 600 | wampusirpi
# No data found...
# Processing Record 474 of 600 | cherdyn
# Processing Record 475 of 600 | ofaqim
# Processing Record 476 of 600 | imeni poliny osipenko
# Processing Record 477 of 600 | vestmannaeyjar
# Processing Record 478 of 600 | oskarshamn
# Processing Record 479 of 600 | manzil jamil
# No data found...
# Processing Record 480 of 600 | fortuna
# Processing Record 481 of 600 | yuzhno-yeniseyskiy
# No data found...
# Processing Record 482 of 600 | matara
# Processing Record 483 of 600 | hofn
# Processing Record 484 of 600 | ndola
# Processing Record 485 of 600 | maua
# Processing Record 486 of 600 | kremenki
# Processing Record 487 of 600 | nichinan
# Processing Record 488 of 600 | louis trichardt
# Processing Record 489 of 600 | villa sandino
# Processing Record 490 of 600 | huarmey
# Processing Record 491 of 600 | tautira
# Processing Record 492 of 600 | karratha
# Processing Record 493 of 600 | veliki preslav
# Processing Record 494 of 600 | petropavlovsk-kamchatskiy
# Processing Record 495 of 600 | kudahuvadhoo
# Processing Record 496 of 600 | georgiyevskoye
# Processing Record 497 of 600 | manokwari
# Processing Record 498 of 600 | avera
# Processing Record 499 of 600 | nouadhibou
# Processing Record 500 of 600 | zharkent
# Processing Record 501 of 600 | massa marittima
# Processing Record 502 of 600 | doha
# Processing Record 503 of 600 | ekimchan
# Processing Record 504 of 600 | kavaratti
# Processing Record 505 of 600 | tambopata
# Processing Record 506 of 600 | port-gentil
# Processing Record 507 of 600 | naze
# Processing Record 508 of 600 | byron bay
# Processing Record 509 of 600 | cayenne
# Processing Record 510 of 600 | peleduy
# Processing Record 511 of 600 | kangaatsiaq
# Processing Record 512 of 600 | visby
# Processing Record 513 of 600 | toliary
# No data found...
# Processing Record 514 of 600 | aksarka
# Processing Record 515 of 600 | graham
# Processing Record 516 of 600 | faya
# Processing Record 517 of 600 | sukhobezvodnoye
# Processing Record 518 of 600 | khonuu
# No data found...
# Processing Record 519 of 600 | tuljapur
# Processing Record 520 of 600 | kalmunai
# Processing Record 521 of 600 | vao
# Processing Record 522 of 600 | batagay-alyta
# Processing Record 523 of 600 | jatiroto
# Processing Record 524 of 600 | ixtapa
# Processing Record 525 of 600 | stornoway
# Processing Record 526 of 600 | axim
# Processing Record 527 of 600 | bata
# Processing Record 528 of 600 | kadykchan
# No data found...
# Processing Record 529 of 600 | dire
# Processing Record 530 of 600 | comodoro rivadavia
# Processing Record 531 of 600 | matamba
# Processing Record 532 of 600 | capitao poco
# Processing Record 533 of 600 | colon
# Processing Record 534 of 600 | havre-saint-pierre
# Processing Record 535 of 600 | kulevcha
# Processing Record 536 of 600 | pimentel
# Processing Record 537 of 600 | mporokoso
# Processing Record 538 of 600 | filingue
# Processing Record 539 of 600 | belyy
# Processing Record 540 of 600 | saint-pierre
# Processing Record 541 of 600 | ankara
# Processing Record 542 of 600 | sorong
# Processing Record 543 of 600 | pacific grove
# Processing Record 544 of 600 | puerto baquerizo moreno
# Processing Record 545 of 600 | saint-augustin
# Processing Record 546 of 600 | jacqueville
# Processing Record 547 of 600 | sumbawa
# No data found...
# Processing Record 548 of 600 | sfantu gheorghe
# Processing Record 549 of 600 | roebourne
# Processing Record 550 of 600 | saryg-sep
# Processing Record 551 of 600 | golspie
# Processing Record 552 of 600 | vanavara
# Processing Record 553 of 600 | tazovskiy
# Processing Record 554 of 600 | vilyuysk
# Processing Record 555 of 600 | el wasta
# No data found...
# Processing Record 556 of 600 | sovetskiy
# Processing Record 557 of 600 | dingle
# Processing Record 558 of 600 | sao joao da barra
# Processing Record 559 of 600 | challans
# Processing Record 560 of 600 | zabid
# Processing Record 561 of 600 | beringovskiy
# Processing Record 562 of 600 | moerai
# Processing Record 563 of 600 | bonthe
# Processing Record 564 of 600 | kalundborg
# Processing Record 565 of 600 | toktogul
# Processing Record 566 of 600 | buluang
# Processing Record 567 of 600 | touros
# Processing Record 568 of 600 | temple
# Processing Record 569 of 600 | grand forks
# Processing Record 570 of 600 | dargaville
# Processing Record 571 of 600 | colombo
# Processing Record 572 of 600 | camacari
# Processing Record 573 of 600 | homer
# Processing Record 574 of 600 | yanam
# Processing Record 575 of 600 | constitucion
# Processing Record 576 of 600 | verkhoyansk
# Processing Record 577 of 600 | kemijarvi
# Processing Record 578 of 600 | kununurra
# Processing Record 579 of 600 | lerwick
# Processing Record 580 of 600 | vanimo
# Processing Record 581 of 600 | murgab
# Processing Record 582 of 600 | malanje
# Processing Record 583 of 600 | rock hill
# Processing Record 584 of 600 | yulara
# Processing Record 585 of 600 | lamar
# Processing Record 586 of 600 | adiake
# Processing Record 587 of 600 | seymchan
# Processing Record 588 of 600 | balikpapan
# Processing Record 589 of 600 | cibitoke
# Processing Record 590 of 600 | kurilsk
# Processing Record 591 of 600 | forio
# Processing Record 592 of 600 | villa bruzual
# Processing Record 593 of 600 | nome
# Processing Record 594 of 600 | khani
# Processing Record 595 of 600 | kumla
# Processing Record 596 of 600 | krasnovishersk
# Processing Record 597 of 600 | karasjok
# Processing Record 598 of 600 | praia da vitoria
# Processing Record 599 of 600 | salym
# Processing Record 600 of 600 | jiuquan

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
WeatherPy_df.to_csv("Output/WeatherData2020Oct30.csv", encoding="utf-8", index=False, header=True)
WeatherPy_df.head(10)
# Out:
#               City  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0  arraial do cabo    -22.97     -42.03            71.29          81.0
# 1           dikson     73.51      80.55            14.59          96.0
# 2           sabang      5.89      95.32            82.31          74.0
# 3         coquimbo    -29.95     -71.34            53.60          87.0
# 4        carnarvon    -24.87     113.63            77.00          65.0
# 5       chokurdakh     70.63     147.92            10.09          96.0
# 6      tuktoyaktuk     69.45    -133.04             3.20          84.0
# 7      new norfolk    -42.78     147.06            69.21          38.0
# 8        cape town    -33.93      18.42            55.35          66.0
# 9           curuca     -0.73     -47.85            76.66          85.0
#
#    Cloudiness (%)  Wind Speed (mph)
# 0           100.0             26.82
# 1            97.0             27.04
# 2            98.0             10.65
# 3            90.0              5.82
# 4            79.0             13.33
# 5           100.0              7.63
# 6            40.0              9.17
# 7            11.0              5.01
# 8             0.0             19.46
# 9            25.0              6.49

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
print(WeatherPy_df["Humidity (%)"].max())
print(WeatherPy_df["Humidity (%)"].max())
print(WeatherPy_df.count())
print("There are no cities that have humidity > 100%")
# Out:
# 100.0
# 100.0
# City                551
# Latitude            551
# Longitude           551
# Temperature (F)     551
# Humidity (%)        551
# Cloudiness (%)      551
# Wind Speed (mph)    551
# dtype: int64
# There are no cities that have humidity > 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(WeatherPy_df['Latitude'],WeatherPy_df['Temperature (F)'], marker ="o", facecolors="purple", edgecolors="black")
plt.title('Latitude vs Temperature on October 30th, 2020')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid()
plt.savefig('Output.10302020TempvsLat.png')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# There appears to be a parabolic relation between temperature and latitude, with the peak temperature being near the Equator, due to the globe-like nature of the earth causing more of the Sun's light rays to hit near the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(WeatherPy_df['Latitude'], WeatherPy_df['Humidity (%)'], marker="o", facecolors="maroon", edgecolors='black')
plt.title('Latitude vs Humidity Percentage on October 30th, 2020')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig('Output/10302020HumidvsLat.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(WeatherPy_df['Latitude'], WeatherPy_df['Cloudiness (%)'], marker='o', facecolors='gold', edgecolors='black')
plt.title('Latitude vs Cloudiness Percent on October 30th, 2020')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig('Output/10302020LatvsCloud.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(WeatherPy_df['Latitude'], WeatherPy_df['Wind Speed (mph)'], marker='*', facecolors='cyan', edgecolors='black')
plt.title('Latitude vs Wind Speed (mph) on October 30, 2020')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig('Output/10302020LatvsWindSpeed.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#create df for northern and southern hemisphere
Ncities=WeatherPy_df.loc[WeatherPy_df["Latitude"]>=0,:]
Scities=WeatherPy_df.loc[WeatherPy_df["Latitude"]<=0,:]
print(Ncities.count())
print(Scities.count())
# Out:
# City                369
# Latitude            369
# Longitude           369
# Temperature (F)     369
# Humidity (%)        369
# Cloudiness (%)      369
# Wind Speed (mph)    369
# dtype: int64
# City                182
# Latitude            182
# Longitude           182
# Temperature (F)     182
# Humidity (%)        182
# Cloudiness (%)      182
# Wind Speed (mph)    182
# dtype: int64

# %% [markdown]
# This distribution makes sense, because the Southern Hemisphere accounts for roughly 32% of Earth's land area.

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
temp=Ncities['Temperature (F)']
latty=Ncities['Latitude']

slope, intercept, r_val, p_val, std_err = st.linregress(latty,temp)
fit= slope * temp + intercept
plt.scatter(latty, temp, marker='o', facecolors='gold', edgecolors='maroon')
plt.plot(temp, fit, "--", color='black')

print(f"The r-value is {r_val}.")

plt.title('Northern Hemisphere: Current Temperature vs City Latitude on October 30, 2020')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid()
plt.annotate(f"y={round(slope,2)}x + {round(intercept,2)}", (-3,15), size=14, c='maroon')
plt.savefig('Output/10302020NLatvsTempREGRESSION.png')
plt.show()
# Out:
# The r-value is -0.8940886775186084.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
temp=Scities['Temperature (F)']
latty=Scities['Latitude']

slope, intercept, r_val, p_val, std_err = st.linregress(latty,temp)
fit= slope * temp + intercept
plt.scatter(latty, temp, marker='o', facecolors='gold', edgecolors='maroon')


m, b = np.polyfit(latty,temp, 1)
plt.plot(latty, m*latty+b)

print(f"The r-value is {r_val}.")

plt.title('Southern Hemisphere: Current Temperature vs City Latitude on October 30, 2020')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid()
plt.annotate(f"y={round(m,2)}x + {round(b,2)}", (-50,90), size=14, c='maroon')
plt.savefig('Output/10302020SLatvsTempREGRESSION.png')
plt.show()
# Out:
# The r-value is 0.6395035727237124.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
humidity=Ncities['Humidity (%)']
latty=Ncities['Latitude']

slope, intercept, r_val, p_val, std_err = st.linregress(latty,humidity)
fit= slope * latty + intercept
plt.scatter(latty, humidity, marker='o', facecolors='gold', edgecolors='maroon')


m, b = np.polyfit(latty,humidity, 1)
plt.plot(latty, m*latty+b)

print(f"The r-value is {r_val}.")

plt.title('Northern Hemisphere: Current Humidity (%) vs City Latitude on October 30, 2020')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.annotate(f"y={round(m,2)}x + {round(b,2)}", (50,30), size=14, c='maroon')
plt.savefig('Output/10302020NLatvsHumidREGRESSION.png')
plt.show()
# Out:
# The r-value is 0.2725786528018972.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
humidity=Scities['Humidity (%)']
latty=Scities['Latitude']

slope, intercept, r_val, p_val, std_err = st.linregress(latty,humidity)
fit= slope * latty + intercept
plt.scatter(latty, humidity, marker='o', facecolors='gold', edgecolors='maroon')


m, b = np.polyfit(latty,humidity, 1)
plt.plot(latty, m*latty+b)

print(f"The r-value is {r_val}.")

plt.title('Southern Hemisphere: Current Humidity (%) vs City Latitude on October 30, 2020')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.annotate(f"y={round(m,2)}x + {round(b,2)}", (-50,20), size=14, c='maroon')
plt.savefig('Output/10302020SLatvsHumidREGRESSION.png')
plt.show()
# Out:
# The r-value is 0.16304470443014007.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Cloudiness=Ncities['Cloudiness (%)']
latty=Ncities['Latitude']

slope, intercept, r_val, p_val, std_err = st.linregress(latty,Cloudiness)
fit= slope * latty + intercept
plt.scatter(latty, Cloudiness, marker='o', facecolors='gold', edgecolors='maroon')


m, b = np.polyfit(latty,Cloudiness, 1)
plt.plot(latty, m*latty+b)

print(f"The r-value is {r_val}.")

plt.title('Southern Hemisphere: Current Cloudiness (%) vs City Latitude on October 30, 2020')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.annotate(f"y={round(m,2)}x + {round(b,2)}", (30,60), size=14, c='maroon')
plt.savefig('Output/10302020NLatvsCloudREGRESSION.png')
plt.show()
# Out:
# The r-value is 0.1489101744521598.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Cloudiness=Scities['Cloudiness (%)']
latty=Scities['Latitude']

slope, intercept, r_val, p_val, std_err = st.linregress(latty,Cloudiness)
fit= slope * latty + intercept
plt.scatter(latty, Cloudiness, marker='o', facecolors='gold', edgecolors='maroon')


m, b = np.polyfit(latty,Cloudiness, 1)
plt.plot(latty, m*latty+b)

print(f"The r-value is {r_val}.")

plt.title('Southern Hemisphere: Current Cloudiness (%) vs City Latitude on October 30, 2020')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.annotate(f"y={round(m,2)}x + {round(b,2)}", (-50,30), size=14, c='maroon')
plt.savefig('Output/10302020SLatvsCloudREGRESSION.png')
plt.show()
# Out:
# The r-value is 0.23871873573735808.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
windspeedmph=Ncities['Wind Speed (mph)']
latty=Ncities['Latitude']

slope, intercept, r_val, p_val, std_err = st.linregress(latty,windspeedmph)
fit= slope * latty + intercept
plt.scatter(latty, windspeedmph, marker='o', facecolors='gold', edgecolors='maroon')


m, b = np.polyfit(latty,windspeedmph, 1)
plt.plot(latty, m*latty+b)

print(f"The r-value is {r_val}.")

plt.title('Southern Hemisphere: Current Wind Speed (mph) vs City Latitude on October 30, 2020')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.annotate(f"y={round(m,2)}x + {round(b,2)}", (10,35), size=14, c='maroon')
plt.savefig('Output/10302020NLatvsWindREGRESSION.png')
plt.show()
# Out:
# The r-value is 0.149340352237335.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
windspeedmph=Scities['Wind Speed (mph)']
latty=Scities['Latitude']

slope, intercept, r_val, p_val, std_err = st.linregress(latty,windspeedmph)
fit= slope * latty + intercept
plt.scatter(latty, windspeedmph, marker='o', facecolors='gold', edgecolors='maroon')


m, b = np.polyfit(latty,windspeedmph, 1)
plt.plot(latty, m*latty+b)

print(f"The r-value is {r_val}.")

plt.title('Southern Hemisphere: Current Wind Speed (mph) vs City Latitude on October 30, 2020')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.annotate(f"y={round(m,2)}x + {round(b,2)}", (-50,20), size=14, c='maroon')
plt.savefig('Output/10302020SLatvsWindREGRESSION.png')
plt.show()
# Out:
# The r-value is -0.24585802686000055.
